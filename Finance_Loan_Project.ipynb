# %% [markdown]
# # Import All The Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

# %% [markdown]
# ### Import Data

# %%
df = pd.read_excel("E:/DATA set/Finance_Loan/financial_loan.xlsx")

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
df.tail()
# Out:
#            id address_state application_type emp_length  \
# 38571  803452            NJ       INDIVIDUAL   < 1 year
# 38572  970377            NY       INDIVIDUAL    8 years
# 38573  875376            CA       INDIVIDUAL    5 years
# 38574  972997            NY       INDIVIDUAL    5 years
# 38575  682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 38571         Joseph M Sanzari Company     C       MORTGAGE 2021-07-11
# 38572                        Swat Fame     C           RENT 2021-10-11
# 38573  Anaheim Regional Medical Center     D           RENT 2021-09-11
# 38574               Brooklyn Radiology     D           RENT 2021-10-11
# 38575                    Allen Edmonds     F           RENT 2021-07-11
#
#       last_credit_pull_date last_payment_date  ... sub_grade        term  \
# 38571            2021-05-16        2021-05-16  ...        C1   60 months
# ...

# %%
print("Total No Of Rows:",df.shape[0])
# Out:
# Total No Of Rows: 38576

# %%
print("Total No Of Columns:",df.shape[1])
# Out:
# Total No Of Columns: 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id                     issue_date  \
# count  3.857600e+04                          38576
# mean   6.810371e+05  2021-07-16 02:31:35.562007040
# min    5.473400e+04            2021-01-01 00:00:00
# 25%    5.135170e+05            2021-04-11 00:00:00
# 50%    6.627280e+05            2021-07-11 00:00:00
# 75%    8.365060e+05            2021-10-11 00:00:00
# max    1.077501e+06            2021-12-12 00:00:00
# std    2.113246e+05                            NaN
#
#                last_credit_pull_date              last_payment_date  \
# count                          38576                          38576
# mean   2021-06-08 13:36:34.193280512  2021-06-26 09:52:08.909166080
# min              2021-01-08 00:00:00            2021-01-08 00:00:00
# 25%              2021-04-15 00:00:00            2021-03-16 00:00:00
# 50%              2021-05-16 00:00:00            2021-06-14 00:00:00
# 75%              2021-08-13 00:00:00            2021-09-15 00:00:00
# ...

# %%
df.isna().sum()
# Out:
# id                          0
# address_state               0
# application_type            0
# emp_length                  0
# emp_title                1438
# grade                       0
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# sub_grade                   0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# dtype: int64

# %%
df["emp_title"]=df["emp_title"].fillna("Unknown")

# %%
df.loc[df["emp_title"] == "Unknown","id"].count()
# Out:
# np.int64(1438)

# %%
Percentage_of_Unknown=(df["emp_title"] == "Unknown").mean()*100
Percentage_of_Unknown
# Out:
# np.float64(3.7277063459145583)

# %% [markdown]
# ### Total Loan Applications

# %%
Total_Loan_Applications=df.id.count()
print("Total_Loan_Applications:",Total_Loan_Applications)
# Out:
# Total_Loan_Applications: 38576

# %% [markdown]
# ### MTD Total Loan Applications

# %%
Latest_Issue_Date = df["issue_date"].max()
Latest_Month=Latest_Issue_Date.month
Latest_Year=Latest_Issue_Date.year
MTD_Data=df[(df["issue_date"].dt.year==Latest_Year) & (df["issue_date"].dt.month==Latest_Month)]
MTD_Total_Applications=MTD_Data["id"].count()
print(f"Total MTD Applications (for {Latest_Issue_Date.strftime('%B %Y')}): {MTD_Total_Applications}")
# Out:
# Total MTD Applications (for December 2021): 4314

# %% [markdown]
# ### Total Funded Amount

# %%
Total_Funded_Amount=df["loan_amount"].sum()
Total_Funded_Amount_million=Total_Funded_Amount/1000000
print(f"Total Funded Amount : ${Total_Funded_Amount_million:.2f}M")
# Out:
# Total Funded Amount : $435.76M

# %% [markdown]
# ### MTD Total Funded Amount

# %%
Latest_Issue_Date = df["issue_date"].max()
Latest_Month=Latest_Issue_Date.month
Latest_Year=Latest_Issue_Date.year
MTD_Data=df[(df["issue_date"].dt.year==Latest_Year) & (df["issue_date"].dt.month==Latest_Month)]
MTD_Total_Funded_Amount=MTD_Data["loan_amount"].sum()
MTD_Total_Funded_Amount_Million=MTD_Total_Funded_Amount/1000000
print(f"Total Fund Amount (for {Latest_Issue_Date.strftime('%B %Y')}) : ${MTD_Total_Funded_Amount_Million:.2f}M")
# Out:
# Total Fund Amount (for December 2021) : $53.98M

# %% [markdown]
# ### Total Amount Received

# %%
Total_Amount_Received=df["total_payment"].sum()
Total_Amount_Received_million=Total_Amount_Received/1000000
print(f"Total Amount Received : ${Total_Amount_Received_million:.2f}M")
# Out:
# Total Amount Received : $473.07M

# %% [markdown]
# ### MTD Total Amount Received

# %%
Latest_Issue_Date = df["issue_date"].max()
Latest_Month=Latest_Issue_Date.month
Latest_Year=Latest_Issue_Date.year
MTD_Data=df[(df["issue_date"].dt.year==Latest_Year) & (df["issue_date"].dt.month==Latest_Month)]
MTD_Total_Amount_Received=MTD_Data["total_payment"].sum()
MTD_Total_Amount_Received_Million=MTD_Total_Amount_Received/1000000
print(f"Total Amount Received (for {Latest_Issue_Date.strftime('%B %Y')}) : ${ MTD_Total_Amount_Received_Million:.2f}M")
# Out:
# Total Amount Received (for December 2021) : $58.07M

# %% [markdown]
# ### Average Interest

# %%
Average_Interest_Rate=df["int_rate"].mean()*100
print(f"Average Interest Rate : {Average_Interest_Rate:.2f}%")
# Out:
# Average Interest Rate : 12.05%

# %% [markdown]
# ### Avg DTI Rate

# %%
Average_DTI_Rate=df["dti"].mean()*100
print(f"Average DTI Rate : {Average_DTI_Rate:.2f}%")
# Out:
# Average DTI Rate : 13.33%

# %% [markdown]
# ### Good Loan

# %%
Good_Loan=df[df["loan_status"].isin(["Current","Fully Paid"])]
Good_Loan_Applications=Good_Loan["id"].count()
Good_Loan_Funded_Amount=Good_Loan["loan_amount"].sum()
Good_Loan_Received_Amount=Good_Loan["total_payment"].sum()
Good_Loan_Funded_Amount_Millions=Good_Loan_Funded_Amount/1000000
Good_Loan_Received_Amount_Millions=Good_Loan_Received_Amount/1000000
Good_Loan_Percentage=Good_Loan_Applications/Total_Loan_Applications*100
print("Total Applications : ",Total_Loan_Applications)
print("Total Good Loan Applications : ",Good_Loan_Applications)
print(f"Total Good Loan Funded Amount : ${Good_Loan_Funded_Amount_Millions:.2f}M")
print(f"Total Good Loan Received Amount : ${Good_Loan_Received_Amount_Millions:.2f}M")
print(f"Total Good Loan Percentage : {Good_Loan_Percentage:.2f}%")
# Out:
# Total Applications :  38576
# Total Good Loan Applications :  33243
# Total Good Loan Funded Amount : $370.22M
# Total Good Loan Received Amount : $435.79M
# Total Good Loan Percentage : 86.18%

# %% [markdown]
# ### Bad Loan

# %%
Bad_Loan=df[df["loan_status"].isin(["Charged Off"])]
Bad_Loan_Applications=Bad_Loan["id"].count()
Bad_Loan_Funded_Amount=Bad_Loan["loan_amount"].sum()
Bad_Loan_Received_Amount=Bad_Loan["total_payment"].sum()
Bad_Loan_Funded_Amount_Millions=Bad_Loan_Funded_Amount/1000000
Bad_Loan_Received_Amount_Millions=Bad_Loan_Received_Amount/1000000
Bad_Loan_Percentage=Bad_Loan_Applications/Total_Loan_Applications*100
print("Total Applications : ",Total_Loan_Applications)
print("Total Bad Loan Applications : ",Bad_Loan_Applications)
print(f"Total Bad Loan Funded Amount : ${Bad_Loan_Funded_Amount_Millions:.2f}M")
print(f"Total Bad Loan Received Amount : ${Bad_Loan_Received_Amount_Millions:.2f}M")
print(f"Total Bad Loan Percentage : {Bad_Loan_Percentage:.2f}%")
# Out:
# Total Applications :  38576
# Total Bad Loan Applications :  5333
# Total Bad Loan Funded Amount : $65.53M
# Total Bad Loan Received Amount : $37.28M
# Total Bad Loan Percentage : 13.82%

# %% [markdown]
# ### Purpose Type

# %%
Loan_Purpose=df.groupby("purpose").size()
Loan_Purpose
# Out:
# purpose
# Debt consolidation    18214
# car                    1497
# credit card            4998
# educational             315
# home improvement       2876
# house                   366
# major purchase         2110
# medical                 667
# moving                  559
# other                  3824
# renewable_energy         94
# small business         1776
# vacation                352
# wedding                 928
# dtype: int64

# %% [markdown]
# ### Monthly Trends By Issue Date For Total Funded Amount

# %%
monthly_funded = (
    df.sort_values("issue_date")
    .assign(month_name=lambda x: x["issue_date"].dt.strftime("%b %Y"))
    .groupby("month_name", sort=False)["loan_amount"]
    .sum()
    .div(1000000)
    .reset_index(name="loan_amount_millions")
)

plt.figure(figsize=(10,5))
plt.fill_between(
    monthly_funded['month_name'],
    monthly_funded['loan_amount_millions'],
    color='skyblue', alpha=0.5
)
plt.plot(
    monthly_funded['month_name'],
    monthly_funded["loan_amount_millions"],
    color="blue", linewidth=2
)

for i, row in monthly_funded.iterrows():
    plt.text(
        i,
        row["loan_amount_millions"] + 0.1,
        f"{row['loan_amount_millions']:.2f}",
        ha='center', va="bottom", fontsize=9, rotation=0,
        color="black"
    )

plt.title("Total Funded Amount By Month", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Funded Amount ($ Millions)")
plt.xticks(
    ticks=range(len(monthly_funded)),
    labels=monthly_funded["month_name"],
    rotation=45
)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly Trends By Issue Date For Total Amount Received

# %%
monthly_received = (
    df.sort_values('issue_date')
    .assign(month_name=lambda x: x['issue_date'].dt.strftime('%b %Y'))
    .groupby('month_name', sort=False)['total_payment']
    .sum()
    .div(1000000)
    .reset_index(name='received_amount_millions')
)

plt.figure(figsize=(10, 5))
plt.fill_between(
    monthly_received['month_name'],
    monthly_received['received_amount_millions'],
    color='lightgreen', alpha=0.5
)
plt.plot(
    monthly_received['month_name'],
    monthly_received['received_amount_millions'],
    color='green', linewidth=2
)

for i, row in monthly_received.iterrows():
    plt.text(
        i,
        row['received_amount_millions'] + 0.1,
        f"{row['received_amount_millions']:.2f}",
        ha='center', va='bottom', fontsize=9, rotation=0, color='black'
    )

plt.title('Total Received Amount by Month', fontsize=14)
plt.xlabel('Month')
plt.ylabel('Received Amount ($ Millions)')
plt.xticks(
    ticks=range(len(monthly_received)),
    labels=monthly_received['month_name'],
    rotation=45
)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly Trends By Issue Date For Total Loan Applications Received

# %%
monthly_applications = (
    df.sort_values('issue_date')
    .assign(month_name=lambda x: x['issue_date'].dt.strftime('%b %Y'))
    .groupby('month_name', sort=False)['id']
    .count()
    .reset_index(name='loan_applications_count')
)

plt.figure(figsize=(10, 5))
plt.fill_between(
    monthly_applications['month_name'],
    monthly_applications['loan_applications_count'],
    color='orange', alpha=0.5
)
plt.plot(
    monthly_applications['month_name'],
    monthly_applications['loan_applications_count'],
    color='darkorange', linewidth=2
)

for i, row in monthly_applications.iterrows():
    plt.text(
        i,
        row['loan_applications_count'] + 0.5,
        f"{row['loan_applications_count']}",
        ha='center', va='bottom', fontsize=9, rotation=0, color='black'
    )

plt.title('Total Loan Applications by Month', fontsize=14)
plt.xlabel('Month')
plt.ylabel('Number of Applications')
plt.xticks(
    ticks=range(len(monthly_applications)),
    labels=monthly_applications['month_name'],
    rotation=45
)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State For Total Funded Amount

# %%
state_funding = (
    df.groupby('address_state')['loan_amount']
    .sum()
    .sort_values(ascending=True)
)
state_funding_thousands = state_funding / 1000

plt.figure(figsize=(10, 8))
bars = plt.barh(
    state_funding_thousands.index,
    state_funding_thousands.values,
    color='lightcoral'
)

for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 10,
        bar.get_y() + bar.get_height() / 2,
        f'{width:,.0f}K',
        va='center',
        fontsize=9
    )

plt.title('Total Funded Amount by State (in ₹ Thousands)')
plt.xlabel("Funded Amount (₹ '000)")
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State For Total Amount Received

# %%
state_received = (
    df.groupby('address_state')["total_payment"]
    .sum()
    .sort_values(ascending=True)
)
state_received_thousands = state_received / 1000

plt.figure(figsize=(10, 8))
bars = plt.barh(
    state_received_thousands.index,
    state_received_thousands.values,
    color='green'
)

for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 10,
        bar.get_y() + bar.get_height() / 2,
        f'{width:,.0f}K',
        va='center',
        fontsize=9
    )

plt.title('Total Amount Received by State (in $ Thousands)')
plt.xlabel("Amount Received($ '000)")
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State For Total Applications Received

# %%
applications_received = (
    df.groupby('address_state')["id"]
    .count()
    .sort_values(ascending=True)
)

plt.figure(figsize=(10, 8))
bars = plt.barh(
    applications_received.index,
    applications_received.values,
    color='teal'
)

for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 100,  # shift labels a little right
        bar.get_y() + bar.get_height() / 2,
        f'{width:,}',   # show exact number with commas
        va='center',
        fontsize=9
    )

plt.title('Total Applications Received by State')
plt.xlabel("Applications Received")
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Term Analysis By Total Funded Amount

# %%
term_funding_millions = df.groupby('term')['loan_amount'].sum() / 1_000_000
plt.figure(figsize=(6, 6))
wedges, texts, autotexts = plt.pie(
    term_funding_millions,
    labels=term_funding_millions.index,
    autopct=lambda pct: f"{pct:.1f}%\n${pct/100 * term_funding_millions.sum():.1f}M",
    startangle=90,
    wedgeprops={'width': 0.4}
)
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color='white'))
plt.title("Total Funded Amount by Term (in $ Millions)")
plt.show()

# %% [markdown]
# ### Loan Term Analysis By Total Amount Received

# %%
term_received_millions = df.groupby('term')['total_payment'].sum() / 1_000_000
plt.figure(figsize=(6, 6))
wedges, texts, autotexts = plt.pie(
    term_received_millions,
    labels=term_received_millions.index,
    autopct=lambda pct: f"{pct:.1f}%\n${pct/100 * term_received_millions.sum():.1f}M",
    startangle=90,
    wedgeprops={'width': 0.4}
)
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color='white'))
plt.title("Total Received Amount by Term (in $ Millions)")
plt.show()

# %% [markdown]
# ### Loan Term Analysis By Total Applications Received

# %%
term_app_received = df.groupby('term')['id'].count()
plt.figure(figsize=(6, 6))

wedges, texts, autotexts = plt.pie(
    term_app_received,
    labels=term_app_received.index,
    autopct=lambda pct: f"{pct:.1f}%\n{int(pct/100 * term_app_received.sum()):,}", 
    startangle=90,
    wedgeprops={'width': 0.4}
)

# Add white circle to make donut shape
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color='white'))

plt.title("Total Applications Received by Term")
plt.show()

# %% [markdown]
# ### Employee Length By Total Funded Amount

# %%
emp_funding = df.groupby('emp_length')['loan_amount'].sum().sort_values()
emp_funding_thousands = emp_funding / 1000
plt.figure(figsize=(10, 6))
bars = plt.barh(
    emp_funding_thousands.index,
    emp_funding_thousands.values,
    color='purple'
)
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 5,
        bar.get_y() + bar.get_height() / 2,
        f"${width:,.0f}K",   
        va='center',
        fontsize=9
    )
plt.xlabel("Funded Amount ($ Thousands)")
plt.title("Total Funded Amount by Employment Length")

plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Employee Length By Total Amount Received

# %%
emp_received = df.groupby('emp_length')['total_payment'].sum().sort_values()
emp_received_thousands = emp_funding / 1000
plt.figure(figsize=(10, 6))
bars = plt.barh(
    emp_received_thousands.index,
    emp_received_thousands.values,
    color='orange'
)
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 5,
        bar.get_y() + bar.get_height() / 2,
        f"${width:,.0f}K",   
        va='center',
        fontsize=9
    )
plt.xlabel("Received Amount ($ Thousands)")
plt.title("Total Received Amount by Employment Length")

plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose By Funded Amount

# %%
sns.set_theme(style="whitegrid")
purpose_funding_millions = (
    df.groupby('purpose')['loan_amount']
      .sum()
      .sort_values(ascending=False) / 1_000_000
).reset_index()

plt.figure(figsize=(12, 7))
ax = sns.barplot(
    data=purpose_funding_millions,
    x="loan_amount",
    y="purpose",
    hue="purpose",        
    dodge=False,
    legend=False,
    palette="Blues_r"
)

for i, v in enumerate(purpose_funding_millions["loan_amount"]):
    ax.text(v + 0.2, i, f"{v:.2f}M", va="center", fontsize=10, fontweight="bold")

plt.title("Total Funded Amount by Loan Purpose ($ Millions)", fontsize=16, weight="bold", pad=15)
plt.xlabel("Funded Amount ($ Millions)", fontsize=12)
plt.ylabel("Loan Purpose", fontsize=12)
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose By Received Amount

# %%
purpose_received_millions = (
    df.groupby('purpose')['total_payment']
      .sum()
      .sort_values(ascending=False) / 1_000_000
).reset_index()

plt.figure(figsize=(12, 7))
ax = sns.barplot(
    data=purpose_received_millions,
    x="total_payment",
    y="purpose",
    hue="purpose",       
    dodge=False,
    legend=False,
    palette="Greens_r"
)

for i, v in enumerate(purpose_received_millions["total_payment"]):
    ax.text(v + 0.2, i, f"{v:.2f}M", va="center", fontsize=10, fontweight="bold")

plt.title("Total Received Amount by Loan Purpose ($ Millions)", fontsize=16, weight="bold", pad=15)
plt.xlabel("Received Amount ($ Millions)", fontsize=12)
plt.ylabel("Loan Purpose", fontsize=12)
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose By Applications Received

# %%
purpose_applications = (
    df.groupby('purpose')['id']
      .count()
      .sort_values(ascending=False)
).reset_index()

plt.figure(figsize=(12, 7))
ax = sns.barplot(
    data=purpose_applications,
    x="id",
    y="purpose",
    hue="purpose",        
    dodge=False,
    legend=False,
    palette="crest"
)

for i, v in enumerate(purpose_applications["id"]):
    ax.text(v + 100, i, f"{v:,}", va="center", fontsize=10, fontweight="bold")

plt.title("Total Applications by Loan Purpose", fontsize=16, weight="bold", pad=15)
plt.xlabel("Number of Applications", fontsize=12)
plt.ylabel("Loan Purpose", fontsize=12)
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()
